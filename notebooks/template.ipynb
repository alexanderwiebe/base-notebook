# %% [markdown]
# # Book Title — Chapter X: Chapter Name
#
# > Brief description of what this notebook covers.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Notes

# %% [markdown]
# _Key concepts, summaries, and observations from the chapter._

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1
