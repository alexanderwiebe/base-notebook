# %% [markdown]
# # Book Title — Chapter X: Chapter Name
#
# > Brief description of what this notebook covers.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Theory / Summary
#
# _Key concepts and definitions from the chapter._

# %% [markdown]
# ## Worked Example
#
# _Reproduce or extend an example from the book._

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# ## Notes / Observations
#
# _Personal observations, questions, or connections to other material._
